# %%
import re
a="The finally block is used to execute code that must run regardless of whether an exception occurs or not. It is commonly used for cleanup operations such as closing files, database connections, or releasing resources."
res=re.search("finally",a)
print(res)
# Out:
# <re.Match object; span=(4, 11), match='finally'>

# %%
import re
a="The finally block is used to execute code that must run regardless of whether an exception occurs or not. It is commonly used for cleanup operations such as closing files, database connections, or releasing resources."
res=re.search("accurate",a)
print(res)
# Out:
# None

# %%
import re
a="The finally block is used to execute code that must run regardless of whether an exception occurs or not. It is commonly used for cleanup operations such as closing files, database connections, or releasing resources."
res=re.findall("accurate",a)
print(res)
# Out:
# []

# %%
import re
a="The finally block is used to execute code that must run regardless of whether an exception occurs or not. It is commonly used for cleanup operations such as closing files, database connections, or releasing resources."
res=re.findall("block",a)
print(res)
# Out:
# ['block']

# %%
import re
txt="POWERBI is"
new=re.sub("POWERBI","powerBI",txt)
print(new)
print(txt)
# Out:
# powerBI is
# POWERBI is

# %%
txt="POWERBI is"
new=txt.replace("POWERBI","powerBI")
print(new)
print(txt)
# Out:
# powerBI is
# POWERBI is

# %%
txt="POWERBI is"
new=txt.replace("POWERBI","powerBI")
print(new)
print(txt)
# Out:
# powerBI is
# POWERBI is

# %%
import re
a="order123"
print(re.findall(r"\d",a))
# Out:
# ['1', '2', '3']

# %%
import re
a="order123"
print(re.sub(r"\d"," ",a))
print(a)
# Out:
# order
# order123

# %%
import re
a="order123"
print(re.findall(r"\d+",a))
# Out:
# ['123']

# %%
import re
txt="sales:500 profit:100"
print(re.findall(r"\d+",txt))
# Out:
# ['500', '100']

# %%
import re
mail1="john123@gmail.com"
mail2="web@.com"
mail3="123.com"
print(re.search(r"\w@\w.\w",mail1))
print(re.search(r"\w@\w.\w",mail2))
print(re.search(r"\w@\w.\w",mail3))
# Out:
# <re.Match object; span=(6, 11), match='3@gma'>
# None
# None

# %%
import re
mail1="john123@gmail.com"
mail2="web@.com"
mail3="123.com"
print(re.findall(r"\w@\w.\w",mail1))
print(re.findall(r"\w@\w.\w",mail2))
print(re.findall(r"\w@\w.\w",mail3))
# Out:
# ['3@gma']
# []
# []

# %%
import re
mail1="john123@gmail.com"
mail2="web@.com"
mail3="123.com"
print(re.findall(r"\w+@\w+.\w+",mail1))
print(re.findall(r"\w+@\w+.\w+",mail2))
print(re.findall(r"\w+@\w+.\w+",mail3))
# Out:
# ['john123@gmail.com']
# []
# []

# %%
import re
txt="94567899654"
print(re.findall(r"\d{10}",txt))
# Out:
# ['9456789965']

# %%
import re
txt="94567899654"
print(re.findall(r"\d+",txt))
# Out:
# ['94567899654']

# %%
import re
txt="94567899654"
print(re.search(r"\d+",txt))
# Out:
# <re.Match object; span=(0, 11), match='94567899654'>

# %%
import re
txt="94567899654"
print(re.search(r"\d{10}",txt))
# Out:
# <re.Match object; span=(0, 10), match='9456789965'>
