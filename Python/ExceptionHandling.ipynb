# %%
age=int(input("Enter age"))
print(age)
# Out:
# 67

# %%
try:
    age=int(input("Enter age"))
    print(age)
except:
    print("Invalid age")
# Out:
# 100

# %%
try:
    age=int(input("Enter age"))
    print(age)
except ValueError:
    print("Invalid age")
except SyntaxError:
    print("Invalid System")
# Out:
# Invalid age

# %%
try:
   print("Process")
except:
   print("Error")
finally:
   print("Completed")
# Out:
# Process
# Completed

# %%
try:
    age=int(input("Enter age"))
    print(age)
except ValueError:
    print("Invalid age")
except SyntaxError:
    print("Invalid System")
finally:
    print("Done")
# Out:
# Invalid age
# Done

# %%
try:
    o=open(r"C:\Users\Ramapriya Murugesan\Desktop\DataAnalyticsPortfolio\Python\txt.txt",'r')
except FileNotFoundError:
    print('File not Found')
finally:
    print("File  opened")
# Out:
# File  opened

# %%
#sales[100,1500,None,1000]
#clean_sales
