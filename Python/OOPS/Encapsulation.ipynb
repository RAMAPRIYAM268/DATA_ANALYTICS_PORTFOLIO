# %%
class Employee:
    def __init__(self):
        self.__salary=500000
    def getsalary(self):
        return self.__salary
e1=Employee()
print(e1.getsalary())
# Out:
# 500000

# %%
class Employee:
    def __init__(self):
        self.__salary=500000
    def getsalary(self):
        return self.__salary
e1=Employee()
e1.__salary=-1
print(e1.getsalary())
# Out:
# 500000

# %%
class Employee:
    def __init__(self):
        self.__salary=500000
    def getsalary(self):
        return self.__salary
    def updatesalary(self,salary):
        if salary>0:
            self.__salary=salary
            return"Salary Updated"
        else:
            return "Invalid salary"
    
e1=Employee()

print(e1.getsalary())
print(e1.updatesalary(100000))
print(e1.getsalary())
# Out:
# 500000
# Salary Updated
# 100000

# %%
class Employee:
    def __init__(self):
        self.__salary=500000
    def updatesalary(self,salary):
        if salary>0:
            self.__salary=salary
            return"Salary Updated"
        else:
            return "Invalid salary"
    def getsalary(self):
        return self.__salary
    
e1=Employee()

print(e1.getsalary())
print(e1.updatesalary(100000))
print(e1.getsalary())
# Out:
# 500000
# Salary Updated
# 100000
